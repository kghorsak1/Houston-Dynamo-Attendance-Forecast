# %% [markdown]
# # Scraper for Houston Dynamo

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
import numpy as np

# %%
def scrape_houston_dynamo_games():
    # Set up Chrome options for headless mode
    options = Options()
    #options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    
    # Initialize WebDriver in headless mode
    driver = webdriver.Chrome(options=options)
    driver.get("https://www.houstondynamofc.com/schedule/#date=2019-03-01")

    # Accept cookies if the button is present
    try:
        accept_cookies = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        accept_cookies.click()
        time.sleep(1)  # Brief pause to allow for any page updates
    except Exception:
        # If the cookie button is not found, continue without action
        pass

    # Data storage
    game_urls = []

    # Loop to navigate through each month
    while True:
        # Allow time for the page to load
        time.sleep(2)

        # Parse the page source with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        # Get the current month/year to append to each URL and check stopping condition
        current_month_element = soup.find('h2', class_="sc-dkrFOg dOlYGg")
        current_month = current_month_element.text.strip() if current_month_element else None

        # Stop if the date is beyond November 2024
        if current_month == "November 2024":
            print("Reached November 2024.")
            break

        # Find all matches at Shell Energy Stadium
        for match in soup.find_all('div', class_="sc-eJDSGI iXMEvt mls-c-match-list__match"):
            stadium = match.find('p', class_="sc-bBABsx hpINxp")
            
            if stadium and stadium.text == "Shell Energy Stadium":
                url_tag = match.find('a', href=True)
                if url_tag:
                    game_urls.append({
                        "Month": current_month,
                        "URL": url_tag['href']
                    })

        # Locate and click the "next" button if present
        try:
            next_button = driver.find_element(By.XPATH, "//button[@value='next']")
            ActionChains(driver).move_to_element(next_button).click(next_button).perform()
        except Exception:
            # Exit loop if no next button is found (end of available months)
            print("Reached the last available month.")
            break

    # Close the driver
    driver.quit()

    # Save to DataFrame
    df = pd.DataFrame(game_urls)
    df.to_csv("houston_dynamo_game_urls.csv", index=False)
    return df

# %%
# Call the function
df = scrape_houston_dynamo_games()
print("Scraping completed. Data saved to 'houston_dynamo_game_urls.csv'.")
# Out:
# Reached November 2024.
# Scraping completed. Data saved to 'houston_dynamo_game_urls.csv'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   117 non-null    object
#  1   URL     117 non-null    object
# dtypes: object(2)
# memory usage: 2.0+ KB

# %%
df.head()
# Out:
#         Month                                                URL
# 0  March 2019  https://www.houstondynamofc.com/competitions/m...
# 1  March 2019  https://www.houstondynamofc.com/competitions/c...
# 2  March 2019  https://www.houstondynamofc.com/competitions/m...
# 3  March 2019  https://www.houstondynamofc.com/competitions/m...
# 4  April 2019  https://www.houstondynamofc.com/competitions/m...

# %%
def scrape_game_details(df):

    options = Options()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    # Initialize WebDriver
    driver = webdriver.Chrome(options=options)

    # Data storage
    game_details = []

    # Iterate over each URL in the DataFrame
    for _, row in df.iterrows():
        year = row['Month']
        url = row['URL']

        # Open game URL
        driver.get(url)
        time.sleep(2)  # Allow time for the page to load

        # Accept cookies if the button is present
        try:
            accept_cookies = driver.find_element("id", "onetrust-accept-btn-handler")
            accept_cookies.click()
            time.sleep(1)  # Brief pause to allow for any page updates
        except Exception:
            pass  # If the cookie button is not found, continue

        # Parse page source with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        # Extract date
        date_element = soup.find('div', class_="sc-dkrFOg paOFY mls-c-blockheader__subtitle")
        date = date_element.text.strip() if date_element else None

        # Extract competition name
        competition_element = soup.find('div', class_="sc-gswNZR hhlcUG mls-c-blockheader__title")
        competition_name = competition_element.text.strip() if competition_element else None

        # Extract opponent (from --away div)
        opponent_element = soup.find('div', class_="sc-dmctIk kXXzOo mls-c-club --away")
        if opponent_element:
            opponent_span = opponent_element.find('span', class_="mls-c-club__shortname") or \
                            opponent_element.find('span', class_="mls-c-club__abbreviation")
            opponent = opponent_span.text.strip() if opponent_span else None
        else:
            opponent = None

        # Extract goals scored and goals received
        score_element = soup.find('div', class_="sc-kMjNwy jTBsRm mls-c-scorebug__post")
        if score_element:
            scores = score_element.find_all('span', class_="mls-c-scorebug__score")
            goals_scored = scores[0].text.strip() if len(scores) > 0 else None
            goals_received = scores[1].text.strip() if len(scores) > 1 else None
        else:
            goals_scored = None
            goals_received = None

        # Extract attendance
        attendance = np.nan
        match_facts_section = soup.find('section', class_="mls-l-module mls-l-module--match-facts")
        if match_facts_section:
            facts = match_facts_section.find_all('div', class_="mls-o-match-facts__fact")
            for fact in facts:
                label = fact.find('span', class_="mls-o-match-facts__label")
                if label and "Attendance:" in label.text:
                    value = fact.find('span', class_="mls-o-match-facts__value")
                    attendance = value.text.strip() if value else np.nan
                    break  # Stop after finding the attendance field

        # Debugging Information
        print(f"Attendance Value: {attendance}")
        print(f"Date: {date}, Competition: {competition_name}, Opponent: {opponent}, Goals Scored: {goals_scored}, Goals Received: {goals_received}")

        # Append the details to the list
        game_details.append({
            "Year": year,
            "URL": url,
            "Date": date,
            "Competition": competition_name,
            "Opponent": opponent,
            "Goals Scored": goals_scored,
            "Goals Received": goals_received,
            "Attendance": attendance
        })

    # Close driver
    driver.quit()

    # Save to DataFrame
    details_df = pd.DataFrame(game_details)
    details_df.to_csv("dynamo_game_details_complete.csv", index=False)
    return details_df

# %%
df = pd.read_csv("houston_dynamo_game_urls.csv")  # DataFrame with 'Month' and 'URL' columns
details_df = scrape_game_details(df)
print("Scraping completed. Data saved to 'dynamo_game_details.csv'.")
# Out:
# Attendance Value: 16,827
# Date: Saturday March 2 2019, Competition: MLS Regular Season, Opponent: Salt Lake, Goals Scored: 1, Goals Received: 1
# Attendance Value: nan
# Date: Tuesday March 5 2019, Competition: CONCACAF Champions Cup, Opponent: Tigres, Goals Scored: 0, Goals Received: 2
# Attendance Value: 12,601
# Date: Saturday March 9 2019, Competition: MLS Regular Season, Opponent: Montréal, Goals Scored: 2, Goals Received: 1
# Attendance Value: 13,549
# Date: Saturday March 16 2019, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 3, Goals Received: 2
# Attendance Value: 14,476
# Date: Saturday April 13 2019, Competition: MLS Regular Season, Opponent: San Jose, Goals Scored: 2, Goals Received: 1
# Attendance Value: 15,557
# Date: Saturday April 27 2019, Competition: MLS Regular Season, Opponent: Columbus, Goals Scored: 2, Goals Received: 0
# Attendance Value: 16,521
# Date: Saturday May 4 2019, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 2, Goals Received: 1
# Attendance Value: 13,327
# Date: Wednesday May 15 2019, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,811
# Date: Saturday May 18 2019, Competition: MLS Regular Season, Opponent: D.C., Goals Scored: 2, Goals Received: 1
# Attendance Value: 15,710
# Date: Saturday June 1 2019, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 1, Goals Received: 1
# Attendance Value: 4,765
# Date: Tuesday June 11 2019, Competition: U.S. Open Cup, Opponent: Austin Bold, Goals Scored: 3, Goals Received: 2
# Attendance Value: 4,559
# Date: Tuesday June 18 2019, Competition: U.S. Open Cup, Opponent: Minnesota, Goals Scored: 2, Goals Received: 3
# Attendance Value: 19,531
# Date: Wednesday July 3 2019, Competition: MLS Regular Season, Opponent: New York, Goals Scored: 4, Goals Received: 0
# Attendance Value: 17,219
# Date: Friday July 12 2019, Competition: MLS Regular Season, Opponent: LAFC, Goals Scored: 1, Goals Received: 3
# Attendance Value: 20,315
# Date: None, Competition: None, Opponent: América, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,138
# Date: Saturday July 27 2019, Competition: MLS Regular Season, Opponent: Seattle, Goals Scored: 0, Goals Received: 1
# Attendance Value: 14,250
# Date: Saturday August 3 2019, Competition: MLS Regular Season, Opponent: Chicago, Goals Scored: 0, Goals Received: 1
# Attendance Value: 15,458
# Date: Saturday August 17 2019, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 2, Goals Received: 2
# Attendance Value: 13,566
# Date: Wednesday September 11 2019, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 2, Goals Received: 0
# Attendance Value: 15,146
# Date: Saturday September 21 2019, Competition: MLS Regular Season, Opponent: Orlando, Goals Scored: 2, Goals Received: 1
# Attendance Value: 21,777
# Date: Sunday October 6 2019, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 4, Goals Received: 2
# Attendance Value: 22,039
# Date: Saturday February 29 2020, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 1, Goals Received: 1
# Attendance Value: nan
# Date: Friday August 21 2020, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 0, Goals Received: 0
# Attendance Value: nan
# Date: Wednesday September 2 2020, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 3, Goals Received: 0
# Attendance Value: nan
# Date: Saturday September 5 2020, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 2, Goals Received: 1
# Attendance Value: 2,486
# Date: Saturday September 19 2020, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 2, Goals Received: 2
# Attendance Value: 2,004
# Date: Saturday October 3 2020, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 1, Goals Received: 2
# Attendance Value: 1,582
# Date: Wednesday October 7 2020, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 2, Goals Received: 0
# Attendance Value: 1,328
# Date: Wednesday October 14 2020, Competition: MLS Regular Season, Opponent: Nashville, Goals Scored: 1, Goals Received: 3
# Attendance Value: 2,237
# Date: Saturday October 24 2020, Competition: MLS Regular Season, Opponent: Columbus, Goals Scored: 1, Goals Received: 1
# Attendance Value: 2,327
# Date: Sunday November 8 2020, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 1, Goals Received: 2
# Attendance Value: 6,376
# Date: Friday April 16 2021, Competition: MLS Regular Season, Opponent: None, Goals Scored: None, Goals Received: None
# Attendance Value: 6,376
# Date: Friday April 16 2021, Competition: MLS Regular Season, Opponent: San Jose, Goals Scored: 2, Goals Received: 1
# Attendance Value: 7,850
# Date: Saturday May 1 2021, Competition: MLS Regular Season, Opponent: LAFC, Goals Scored: 1, Goals Received: 1
# Attendance Value: 7,054
# Date: Wednesday May 12 2021, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 1, Goals Received: 0
# Attendance Value: 9,255
# Date: Saturday May 22 2021, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 2, Goals Received: 1
# Attendance Value: 10,791
# Date: Wednesday June 23 2021, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 2, Goals Received: 2
# Attendance Value: 20,021
# Date: Saturday July 3 2021, Competition: MLS Regular Season, Opponent: Cincinnati, Goals Scored: 1, Goals Received: 1
# Attendance Value: 13,462
# Date: Saturday July 31 2021, Competition: MLS Regular Season, Opponent: Salt Lake, Goals Scored: 0, Goals Received: 0
# Attendance Value: 13,908
# Date: Saturday August 14 2021, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 1, Goals Received: 3
# Attendance Value: 13,548
# Date: Saturday August 21 2021, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 2, Goals Received: 2
# Attendance Value: 14,521
# Date: Saturday August 28 2021, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 1, Goals Received: 2
# Attendance Value: 9,872
# Date: Friday September 3 2021, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 0, Goals Received: 2
# Attendance Value: 14,070
# Date: Saturday September 11 2021, Competition: MLS Regular Season, Opponent: Austin, Goals Scored: 3, Goals Received: 0
# Attendance Value: 12,353
# Date: Saturday September 18 2021, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 3, Goals Received: 2
# Attendance Value: 12,114
# Date: Wednesday September 29 2021, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 0, Goals Received: 0
# Attendance Value: 14,265
# Date: Saturday October 16 2021, Competition: MLS Regular Season, Opponent: Seattle, Goals Scored: 2, Goals Received: 1
# Attendance Value: 13,798
# Date: Wednesday October 20 2021, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 0, Goals Received: 3
# Attendance Value: 14,474
# Date: Sunday October 31 2021, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 0, Goals Received: 1
# Attendance Value: 18,561
# Date: Sunday February 27 2022, Competition: MLS Regular Season, Opponent: Salt Lake, Goals Scored: 0, Goals Received: 0
# Attendance Value: 13,028
# Date: Saturday March 12 2022, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 2, Goals Received: 1
# Attendance Value: 17,007
# Date: Saturday March 19 2022, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,414
# Date: Saturday April 9 2022, Competition: MLS Regular Season, Opponent: San Jose, Goals Scored: 4, Goals Received: 3
# Attendance Value: 13,650
# Date: Saturday April 16 2022, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 0, Goals Received: 0
# Attendance Value: 7,983
# Date: Tuesday April 19 2022, Competition: U.S. Open Cup, Opponent: RGV FC, Goals Scored: 2, Goals Received: 1
# Attendance Value: 16,296
# Date: Saturday April 30 2022, Competition: MLS Regular Season, Opponent: Austin, Goals Scored: 1, Goals Received: 2
# Attendance Value: 2,541
# Date: Wednesday May 11 2022, Competition: U.S. Open Cup, Opponent: San Antonio, Goals Scored: 1, Goals Received: 0
# Attendance Value: 16,035
# Date: Saturday May 14 2022, Competition: MLS Regular Season, Opponent: Nashville, Goals Scored: 2, Goals Received: 0
# Attendance Value: 11,093
# Date: Wednesday May 18 2022, Competition: MLS Regular Season, Opponent: Seattle, Goals Scored: 0, Goals Received: 1
# Attendance Value: 13,081
# Date: Saturday June 25 2022, Competition: MLS Regular Season, Opponent: Chicago, Goals Scored: 2, Goals Received: 0
# Attendance Value: 19,242
# Date: Sunday July 3 2022, Competition: MLS Regular Season, Opponent: Charlotte, Goals Scored: 1, Goals Received: 2
# Attendance Value: 21,284
# Date: Saturday July 9 2022, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 2, Goals Received: 2
# Attendance Value: 15,223
# Date: Saturday July 23 2022, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 1, Goals Received: 2
# Attendance Value: 21,284
# Date: Saturday August 13 2022, Competition: MLS Regular Season, Opponent: Montréal, Goals Scored: 2, Goals Received: 3
# Attendance Value: 21,284
# Date: Wednesday August 31 2022, Competition: MLS Regular Season, Opponent: LAFC, Goals Scored: 2, Goals Received: 1
# Attendance Value: 15,169
# Date: Saturday September 10 2022, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 0, Goals Received: 0
# Attendance Value: 10,305
# Date: Tuesday September 13 2022, Competition: MLS Regular Season, Opponent: New England, Goals Scored: 3, Goals Received: 1
# Attendance Value: 21,284
# Date: Sunday October 9 2022, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 1, Goals Received: 3
# Attendance Value: nan
# Date: None, Competition: None, Opponent: None, Goals Scored: None, Goals Received: None
# Attendance Value: 19,047
# Date: Saturday March 18 2023, Competition: MLS Regular Season, Opponent: Austin, Goals Scored: 2, Goals Received: 0
# Attendance Value: 13,024
# Date: Saturday March 25 2023, Competition: MLS Regular Season, Opponent: New York City, Goals Scored: 1, Goals Received: 0
# Attendance Value: 19,128
# Date: Saturday April 8 2023, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 3, Goals Received: 0
# Attendance Value: 16,045
# Date: Saturday April 22 2023, Competition: MLS Regular Season, Opponent: Miami, Goals Scored: 1, Goals Received: 0
# Attendance Value: 13,793
# Date: Saturday May 6 2023, Competition: MLS Regular Season, Opponent: Salt Lake, Goals Scored: 0, Goals Received: 0
# Attendance Value: 5,094
# Date: Wednesday May 10 2023, Competition: U.S. Open Cup, Opponent: Kansas City, Goals Scored: 1, Goals Received: 0
# Attendance Value: 14,061
# Date: Saturday May 13 2023, Competition: MLS Regular Season, Opponent: Seattle, Goals Scored: 0, Goals Received: 1
# Attendance Value: 2,947
# Date: Tuesday May 23 2023, Competition: U.S. Open Cup, Opponent: Minnesota, Goals Scored: 4, Goals Received: 0
# Attendance Value: 16,055
# Date: Saturday May 27 2023, Competition: MLS Regular Season, Opponent: Austin, Goals Scored: 2, Goals Received: 1
# Attendance Value: 15,366
# Date: Saturday June 10 2023, Competition: MLS Regular Season, Opponent: LAFC, Goals Scored: 4, Goals Received: 0
# Attendance Value: 14,249
# Date: Wednesday June 21 2023, Competition: MLS Regular Season, Opponent: San Jose, Goals Scored: 4, Goals Received: 1
# Attendance Value: 16,489
# Date: Saturday July 8 2023, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 2, Goals Received: 2
# Attendance Value: 11,855
# Date: Wednesday July 12 2023, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 0, Goals Received: 3
# Attendance Value: 12,627
# Date: Tuesday July 25 2023, Competition: Leagues Cup, Opponent: Houston, Goals Scored: 2, Goals Received: 2
# Attendance Value: 10,438
# Date: Wednesday August 2 2023, Competition: Leagues Cup, Opponent: Houston, Goals Scored: 0, Goals Received: 0
# Attendance Value: 9,188
# Date: Monday August 7 2023, Competition: Leagues Cup, Opponent: Houston, Goals Scored: 2, Goals Received: 1
# Attendance Value: 12,670
# Date: Sunday August 20 2023, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 5, Goals Received: 0
# Attendance Value: 11,137
# Date: Wednesday August 23 2023, Competition: U.S. Open Cup, Opponent: Salt Lake, Goals Scored: 3, Goals Received: 1
# Attendance Value: 10,873
# Date: Wednesday August 30 2023, Competition: MLS Regular Season, Opponent: Columbus, Goals Scored: 2, Goals Received: 0
# Attendance Value: nan
# Date: None, Competition: None, Opponent: None, Goals Scored: None, Goals Received: None
# Attendance Value: 13,866
# Date: Wednesday September 20 2023, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 4, Goals Received: 1
# Attendance Value: 18,175
# Date: Saturday September 30 2023, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 0, Goals Received: 0
# Attendance Value: 16,430
# Date: Saturday October 7 2023, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 5, Goals Received: 1
# Attendance Value: 17,508
# Date: Sunday October 29 2023, Competition: Audi 2024 MLS Cup Playoffs, Opponent: Salt Lake, Goals Scored: 2, Goals Received: 1
# Attendance Value: 16,374
# Date: Saturday November 11 2023, Competition: Audi 2024 MLS Cup Playoffs, Opponent: Salt Lake, Goals Scored: 1, Goals Received: 1
# Attendance Value: 18,818
# Date: Saturday February 24, Competition: MLS Regular Season, Opponent: Kansas City, Goals Scored: 1, Goals Received: 1
# Attendance Value: nan
# Date: Tuesday February 27, Competition: CONCACAF Champions Cup, Opponent: St. Louis, Goals Scored: 1, Goals Received: 0
# Attendance Value: 16,516
# Date: Saturday March 2, Competition: MLS Regular Season, Opponent: New York, Goals Scored: 1, Goals Received: 2
# Attendance Value: nan
# Date: Wednesday March 6, Competition: CONCACAF Champions Cup, Opponent: Columbus, Goals Scored: 0, Goals Received: 1
# Attendance Value: 16,003
# Date: Saturday March 16, Competition: MLS Regular Season, Opponent: Portland, Goals Scored: 1, Goals Received: 0
# Attendance Value: 16,184
# Date: Saturday March 30, Competition: MLS Regular Season, Opponent: San Jose, Goals Scored: 2, Goals Received: 1
# Attendance Value: 20,115
# Date: Saturday April 20, Competition: MLS Regular Season, Opponent: Austin, Goals Scored: 0, Goals Received: 1
# Attendance Value: 17,212
# Date: Saturday May 4, Competition: MLS Regular Season, Opponent: St. Louis, Goals Scored: 0, Goals Received: 0
# Attendance Value: nan
# Date: Tuesday May 7, Competition: U.S. Open Cup, Opponent: Detroit, Goals Scored: 3, Goals Received: 3
# Attendance Value: 19,284
# Date: Saturday May 18, Competition: MLS Regular Season, Opponent: Dallas, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,237
# Date: Wednesday May 29, Competition: MLS Regular Season, Opponent: Colorado, Goals Scored: 3, Goals Received: 1
# Attendance Value: 15,096
# Date: Wednesday June 19, Competition: MLS Regular Season, Opponent: Seattle, Goals Scored: 2, Goals Received: 2
# Attendance Value: 15,321
# Date: Saturday June 29, Competition: MLS Regular Season, Opponent: Charlotte, Goals Scored: 1, Goals Received: 0
# Attendance Value: 17,142
# Date: Saturday July 13, Competition: MLS Regular Season, Opponent: Minnesota, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,398
# Date: Saturday July 27, Competition: Leagues Cup, Opponent: Atlas, Goals Scored: 0, Goals Received: 1
# Attendance Value: 11,062
# Date: Monday August 5, Competition: Leagues Cup, Opponent: Salt Lake, Goals Scored: 3, Goals Received: 0
# Attendance Value: 13,053
# Date: Friday August 9, Competition: Leagues Cup, Opponent: Houston, Goals Scored: 2, Goals Received: 2
# Attendance Value: 16,640
# Date: Saturday August 24, Competition: MLS Regular Season, Opponent: Toronto, Goals Scored: 0, Goals Received: 1
# Attendance Value: nan
# Date: Saturday September 7, Competition: MLS Regular Season, Opponent: LAFC, Goals Scored: 0, Goals Received: 0
# Attendance Value: 15,862
# Date: Saturday September 14, Competition: MLS Regular Season, Opponent: Salt Lake, Goals Scored: 4, Goals Received: 1
# Attendance Value: 14,282
# Date: Wednesday September 18, Competition: MLS Regular Season, Opponent: Vancouver, Goals Scored: 1, Goals Received: 1
# Attendance Value: 15,358
# Date: Wednesday October 2, Competition: MLS Regular Season, Opponent: New England, Goals Scored: 2, Goals Received: 1
# Attendance Value: 20,800
# Date: Saturday October 19, Competition: MLS Regular Season, Opponent: LA, Goals Scored: 2, Goals Received: 1
# Scraping completed. Data saved to 'dynamo_game_details.csv'.

# %%
details_df.head()
# Out:
#          Year                                                URL  \
# 0  March 2019  https://www.houstondynamofc.com/competitions/m...
# 1  March 2019  https://www.houstondynamofc.com/competitions/c...
# 2  March 2019  https://www.houstondynamofc.com/competitions/m...
# 3  March 2019  https://www.houstondynamofc.com/competitions/m...
# 4  April 2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake            1
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres            0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal            2
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver            3
# 4  Saturday April 13 2019      MLS Regular Season   San Jose            2
#
#   Goals Received Attendance
# 0              1     16,827
# 1              2        NaN
# 2              1     12,601
# 3              2     13,549
# 4              1     14,476

# %% [markdown]
# # Playing with data

# %%
details_df = pd.read_csv("dynamo_game_details_complete.csv")

# %%
details_df[['Month', 'Year']] = details_df['Year'].str.split(' ', expand=True, n=1)

# %%
details_df.head()
# Out:
#    Year                                                URL  \
# 0  2019  https://www.houstondynamofc.com/competitions/m...
# 1  2019  https://www.houstondynamofc.com/competitions/c...
# 2  2019  https://www.houstondynamofc.com/competitions/m...
# 3  2019  https://www.houstondynamofc.com/competitions/m...
# 4  2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent  Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake           1.0
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres           0.0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal           2.0
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver           3.0
# 4  Saturday April 13 2019      MLS Regular Season   San Jose           2.0
#
#    Goals Received Attendance  Month
# 0             1.0     16,827  March
# 1             2.0        NaN  March
# 2             1.0     12,601  March
# 3             2.0     13,549  March
# 4             1.0     14,476  April

# %%
details_df['DOW'] = details_df['Date'].str.split(' ').str[0]

# %%
details_df.head()
# Out:
#    Year                                                URL  \
# 0  2019  https://www.houstondynamofc.com/competitions/m...
# 1  2019  https://www.houstondynamofc.com/competitions/c...
# 2  2019  https://www.houstondynamofc.com/competitions/m...
# 3  2019  https://www.houstondynamofc.com/competitions/m...
# 4  2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent  Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake           1.0
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres           0.0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal           2.0
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver           3.0
# 4  Saturday April 13 2019      MLS Regular Season   San Jose           2.0
#
#    Goals Received Attendance  Month       DOW
# 0             1.0     16,827  March  Saturday
# 1             2.0        NaN  March   Tuesday
# 2             1.0     12,601  March  Saturday
# 3             2.0     13,549  March  Saturday
# 4             1.0     14,476  April  Saturday

# %%
details_df['Attendance'] = details_df['Attendance'].str.replace(',', '').astype(float)

# %%
details_df.head()
# Out:
#    Year                                                URL  \
# 0  2019  https://www.houstondynamofc.com/competitions/m...
# 1  2019  https://www.houstondynamofc.com/competitions/c...
# 2  2019  https://www.houstondynamofc.com/competitions/m...
# 3  2019  https://www.houstondynamofc.com/competitions/m...
# 4  2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent  Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake           1.0
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres           0.0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal           2.0
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver           3.0
# 4  Saturday April 13 2019      MLS Regular Season   San Jose           2.0
#
#    Goals Received  Attendance  Month       DOW
# 0             1.0     16827.0  March  Saturday
# 1             2.0         NaN  March   Tuesday
# 2             1.0     12601.0  March  Saturday
# 3             2.0     13549.0  March  Saturday
# 4             1.0     14476.0  April  Saturday

# %%
grouped_df = details_df.groupby(['Year', 'Month'])['Attendance'].mean().reset_index()

# %%
# Create a MultiIndex Series from grouped_df
attendance_mapping = grouped_df.set_index(['Year', 'Month'])['Attendance']

# %%
# Map the Attendance values to details_df and fill missing values
details_df['Attendance'] = details_df.apply(
    lambda row: attendance_mapping.get((row['Year'], row['Month']), row['Attendance'])
    if pd.isna(row['Attendance']) else row['Attendance'], axis=1
)

# %%
details_df["Attendance"] = details_df["Attendance"].round(0)

# %%
details_df.head()
# Out:
#    Year                                                URL  \
# 0  2019  https://www.houstondynamofc.com/competitions/m...
# 1  2019  https://www.houstondynamofc.com/competitions/c...
# 2  2019  https://www.houstondynamofc.com/competitions/m...
# 3  2019  https://www.houstondynamofc.com/competitions/m...
# 4  2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent  Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake           1.0
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres           0.0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal           2.0
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver           3.0
# 4  Saturday April 13 2019      MLS Regular Season   San Jose           2.0
#
#    Goals Received  Attendance  Month       DOW
# 0             1.0     16827.0  March  Saturday
# 1             2.0     14326.0  March   Tuesday
# 2             1.0     12601.0  March  Saturday
# 3             2.0     13549.0  March  Saturday
# 4             1.0     14476.0  April  Saturday

# %%
details_df.isna().sum()
# Out:
# Year              0
# URL               0
# Date              3
# Competition       3
# Opponent          3
# Goals Scored      3
# Goals Received    3
# Attendance        2
# Month             0
# DOW               3
# dtype: int64

# %%
#Select rows where attendance is null
details_df[details_df['Attendance'].isnull()]
# Out:
#     Year                                                URL  \
# 22  2020  https://www.houstondynamofc.com/competitions/m...
# 68  2023  https://www.houstondynamofc.com/competitions/u...
#
#                      Date         Competition Opponent  Goals Scored  \
# 22  Friday August 21 2020  MLS Regular Season   Dallas           0.0
# 68                    NaN                 NaN      NaN           NaN
#
#     Goals Received  Attendance     Month     DOW
# 22             0.0         NaN    August  Friday
# 68             NaN         NaN  February     NaN

# %%
#Drop rows where attendance is null
details_df = details_df.dropna(subset=['Attendance'])

# %%
details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115 entries, 0 to 116
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            115 non-null    object
#  1   URL             115 non-null    object
#  2   Date            113 non-null    object
#  3   Competition     113 non-null    object
#  4   Opponent        113 non-null    object
#  5   Goals Scored    113 non-null    float64
#  6   Goals Received  113 non-null    float64
#  7   Attendance      115 non-null    float64
#  8   Month           115 non-null    object
#  9   DOW             113 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 9.9+ KB

# %%
#Drop rows where attendance is null
details_df = details_df.dropna(subset=['Date'])

# %%
details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113 entries, 0 to 116
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            113 non-null    object
#  1   URL             113 non-null    object
#  2   Date            113 non-null    object
#  3   Competition     113 non-null    object
#  4   Opponent        112 non-null    object
#  5   Goals Scored    112 non-null    float64
#  6   Goals Received  112 non-null    float64
#  7   Attendance      113 non-null    float64
#  8   Month           113 non-null    object
#  9   DOW             113 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 9.7+ KB

# %%
#if goals scored > goals received then W, if == then D, if < then L
details_df['Result'] = np.where(details_df['Goals Scored'] > details_df['Goals Received'], 'W', np.where(details_df['Goals Scored'] == details_df['Goals Received'], 'D', 'L'))

# %%
details_df.head()
# Out:
#    Year                                                URL  \
# 0  2019  https://www.houstondynamofc.com/competitions/m...
# 1  2019  https://www.houstondynamofc.com/competitions/c...
# 2  2019  https://www.houstondynamofc.com/competitions/m...
# 3  2019  https://www.houstondynamofc.com/competitions/m...
# 4  2019  https://www.houstondynamofc.com/competitions/m...
#
#                      Date             Competition   Opponent  Goals Scored  \
# 0   Saturday March 2 2019      MLS Regular Season  Salt Lake           1.0
# 1    Tuesday March 5 2019  CONCACAF Champions Cup     Tigres           0.0
# 2   Saturday March 9 2019      MLS Regular Season   Montréal           2.0
# 3  Saturday March 16 2019      MLS Regular Season  Vancouver           3.0
# 4  Saturday April 13 2019      MLS Regular Season   San Jose           2.0
#
#    Goals Received  Attendance  Month       DOW Result
# 0             1.0     16827.0  March  Saturday      D
# 1             2.0     14326.0  March   Tuesday      L
# 2             1.0     12601.0  March  Saturday      W
# 3             2.0     13549.0  March  Saturday      W
# 4             1.0     14476.0  April  Saturday      W

# %%
details_df.to_csv("dynamo_games_initial.csv", index=False)
